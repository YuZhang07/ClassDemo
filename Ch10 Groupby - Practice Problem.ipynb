# %%
import pandas as pd

# %%
# %matplotlib notebook

# %%
data = pd.read_csv('data/GameSalary.csv')

# %%
# limiting the display rows
pd.set_option('display.max_rows', 10)
data
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# 2   10552    Leslie       Jean      F           Art                 Artist
# 3   10936     Cusak    Barbara      F   Programming             Programmer
# 4   11048     Noble      Linda      M   Game Design   Senior Game Designer
# ..    ...       ...        ...    ...           ...                    ...
# 88  26679   Whiting      Sarah      F     Animation               Animator
# 89  26813    Denver        Jan      F   Programming             Programmer
# 90  26896   Bermont     Thomas      M   Programming        Lead Programmer
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance
# 0    67000     Average
# ...

# %% [markdown]
# # Soring: df.sort_values(by 'Last Name',ascending = False)

# %%
df = data
# Sorted by last name
df.sort_values(by='Last Name')   # by default ascending = True
# Out:
#        ID   Last Name First Name Gender    Department                  Title  \
# 78  24997       Adams     Martha      F  Sound Design    Lead Sound Designer
# 64  23123     Afflord        Tom      F  Sound Design  Senior Sound Designer
# 0   10000      Aikman       Gary      F  Sound Design  Senior Sound Designer
# 63  22920    Anderson       Jeff      F  Sound Design         Sound Designer
# 90  26896     Bermont     Thomas      M   Programming        Lead Programmer
# ..    ...         ...        ...    ...           ...                    ...
# 88  26679     Whiting      Sarah      F     Animation               Animator
# 71  23837  Williamson       Tina      F     Animation               Animator
# 23  15271      Wilson    Claudia      M     Animation               Animator
# 30  16760        Wood      Jimmy      F           Art          Senior Artist
# 29  16401    Wynperle    Allison      M           Art          Senior Artist
#
#     Salary Performance
# ...

# %%
df.sort_values(by='Salary',ascending = False)
# Out:
#        ID Last Name First Name Gender         Department               Title  \
# 90  26896   Bermont     Thomas      M        Programming     Lead Programmer
# 5   11309   Bobbitt     Oronzo      F        Programming   Senior Programmer
# 33  17466    Parker     Angela      F         Production  Executive Producer
# 74  24334    Bogani       Jane      M        Programming   Senior Programmer
# 42  18845     Brett       Phil      F        Programming   Senior Programmer
# ..    ...       ...        ...    ...                ...                 ...
# 69  23484     Simon    Bridget      F                Art              Artist
# 65  23164   Quinton     Barney      M  Quality Assurance           QA Tester
# 24  15594      Ross       Fred      F  Quality Assurance           QA Tester
# 56  21743   Restery       Mimi      F  Quality Assurance           QA Tester
# 62  22793      Rudy      Jamie      M  Quality Assurance           QA Tester
#
#     Salary Performance
# ...

# %%
# Sorted by two columns

data.sort_values(by=['Gender','Salary'],ascending = False)
# Out:
#        ID Last Name First Name Gender         Department              Title  \
# 90  26896   Bermont     Thomas      M        Programming    Lead Programmer
# 74  24334    Bogani       Jane      M        Programming  Senior Programmer
# 44  19203   Brickey     Wiliam      M        Programming  Senior Programmer
# 16  13183     Fegin      Nancy      M        Programming         Programmer
# 79  25190     Carlo     Criste      M        Programming         Programmer
# ..    ...       ...        ...    ...                ...                ...
# 47  19968      Reed     Robert      F  Quality Assurance          QA Tester
# 59  22284     Moran       Mike      F                Art             Artist
# 69  23484     Simon    Bridget      F                Art             Artist
# 24  15594      Ross       Fred      F  Quality Assurance          QA Tester
# 56  21743   Restery       Mimi      F  Quality Assurance          QA Tester
#
#     Salary Performance
# 90  120000   Excellent
# ...

# %%
df.sort_values(by=['Department','Salary'],ascending = False)
# Out:
#        ID   Last Name First Name Gender    Department                  Title  \
# 78  24997       Adams     Martha      F  Sound Design    Lead Sound Designer
# 64  23123     Afflord        Tom      F  Sound Design  Senior Sound Designer
# 0   10000      Aikman       Gary      F  Sound Design  Senior Sound Designer
# 13  12593     Spinale      Lorna      M  Sound Design         Sound Designer
# 36  17699        Sade      Ringo      M  Sound Design         Sound Designer
# ..    ...         ...        ...    ...           ...                    ...
# 10  12182    Foerster     Shelly      F     Animation        Senior Animator
# 26  15881       Scott      Laura      M     Animation               Animator
# 76  24736   Goldstein     George      M     Animation               Animator
# 71  23837  Williamson       Tina      F     Animation               Animator
# 23  15271      Wilson    Claudia      M     Animation               Animator
#
#     Salary Performance
# ...

# %%
# List three employee who has the lowest Salary
df = data
res = df.sort_values(by='Salary',ascending = True).head(3)
print(res)

res = df.sort_values(by='Salary',ascending = False).tail(3)
res
# Out:
#        ID Last Name First Name Gender         Department      Title  Salary  \
# 62  22793      Rudy      Jamie      M  Quality Assurance  QA Tester   35000
# 24  15594      Ross       Fred      F  Quality Assurance  QA Tester   35000
# 56  21743   Restery       Mimi      F  Quality Assurance  QA Tester   35000
#
#    Performance
# 62     Average
# 24     Average
# 56     Average
#        ID Last Name First Name Gender         Department      Title  Salary  \
# 24  15594      Ross       Fred      F  Quality Assurance  QA Tester   35000
# 56  21743   Restery       Mimi      F  Quality Assurance  QA Tester   35000
# 62  22793      Rudy      Jamie      M  Quality Assurance  QA Tester   35000
#
#    Performance
# 24     Average
# 56     Average
# 62     Average

# %%
# List employee who has the Highest Salary
res = df.sort_values(by='Salary',ascending = True).tail(1)
print(res)

res = df.sort_values(by='Salary',ascending = False).head(1)
res
# Out:
#        ID Last Name First Name Gender   Department            Title  Salary  \
# 90  26896   Bermont     Thomas      M  Programming  Lead Programmer  120000
#
#    Performance
# 90   Excellent
#        ID Last Name First Name Gender   Department            Title  Salary  \
# 90  26896   Bermont     Thomas      M  Programming  Lead Programmer  120000
#
#    Performance
# 90   Excellent

# %%
# List the programmer who has the Highest Salary
res = df[df.Title == 'Programmer'].sort_values(by='Salary',ascending = False)
print(res)

print(res[['Last Name', 'First Name', 'Title',  'Salary']].head(1))
# Out:
#        ID Last Name First Name Gender   Department       Title  Salary  \
# 91  27244  De Maria     Cristi      F  Programming  Programmer   90000
# 16  13183     Fegin      Nancy      M  Programming  Programmer   89000
# 18  13694     White       Jack      F  Programming  Programmer   89000
# 17  13638      Erpf   Meredith      F  Programming  Programmer   85800
# 14  12961    Watson       Fran      F  Programming  Programmer   85750
# ..    ...       ...        ...    ...          ...         ...     ...
# 61  22454      Sapp     Leslie      M  Programming  Programmer   63250
# 7   11447  Sampieri     Maylou      M  Programming  Programmer   61000
# 46  19757      Dill     Jeanne      F  Programming  Programmer   60125
# 89  26813    Denver        Jan      F  Programming  Programmer   58400
# 41  18223    Titley      Kathy      F  Programming  Programmer   50000
#
#    Performance
# 91   Excellent
# 16   Excellent
# 18   Excellent
# 17   Excellent
# 14   Excellent
# ..         ...
# ...

# %%
# Which female employee has the lowest salary, in which department

res = df[ df['Gender'] == 'F'  ].sort_values(by='Salary',ascending = True)


res = res.head(1)

print(res)
print('Department:', res['Department'])
res

names = res.columns
values = res.values

index=0
for name in names:
    print(name, ':', values[0][index])
    index = index+1
# Out:
#        ID Last Name First Name Gender         Department      Title  Salary  \
# 56  21743   Restery       Mimi      F  Quality Assurance  QA Tester   35000
#
#    Performance
# 56     Average
# Department: 56    Quality Assurance
# Name: Department, dtype: object
# ID : 21743
# Last Name : Restery
# First Name : Mimi
# Gender : F
# Department : Quality Assurance
# Title : QA Tester
# Salary : 35000
# Performance : Average

# %%
# Show each department's highest salary

# Show each title's average salary

# Need use groupby

# %% [markdown]
# # Use groupby
#
# # Show each department's highest salary
#
# # Show each title's average salary

# %%
data
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# 2   10552    Leslie       Jean      F           Art                 Artist
# 3   10936     Cusak    Barbara      F   Programming             Programmer
# 4   11048     Noble      Linda      M   Game Design   Senior Game Designer
# ..    ...       ...        ...    ...           ...                    ...
# 88  26679   Whiting      Sarah      F     Animation               Animator
# 89  26813    Denver        Jan      F   Programming             Programmer
# 90  26896   Bermont     Thomas      M   Programming        Lead Programmer
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance
# 0    67000     Average
# ...

# %%
# Show the number of employees
print(len(data))
res = data.groupby(data['Gender']).count()
res
# Out:
# 93
#         ID  Last Name  First Name  Department  Title  Salary  Performance
# Gender
# F       61         61          61          61     61      61           61
# M       32         32          32          32     32      32           32

# %%
# Show the number of employees
print(len(data))
res = data['ID'].groupby(data.Gender).count()
res
# Out:
# 93
# Gender
# F    61
# M    32
# Name: ID, dtype: int64

# %%
# Show the number of employees by each department
print(len(data))
res = data['ID'].groupby(data.Department).count()
res
# Out:
# 93
# Department
# Animation            17
# Art                  25
# Game Design           5
# Production            2
# Programming          25
# Quality Assurance    11
# Sound Design          8
# Name: ID, dtype: int64

# %%
# Compare the average salary of programer by Gender
result = data['Salary'].groupby(data['Gender']).mean()
print(result)  

# result is series
if result['F'] > result['M']:
    print("Female employee has higher salary")
else:
    print("Male employee has higher salary")
# Out:
# Gender
# F    62426.393443
# M    62193.281250
# Name: Salary, dtype: float64
# Female employee has higher salary

# %%
# Compare the average salary of programer by Gender

# Step 1: Get Programmer
df = data

res1 = df[ df.Title == 'Programmer' ]
#print(res1)

# Step 2: groupy and average salary
res2 = res1['Salary'].groupby(data.Gender).mean()
print(res2)

# one step 
res3 = df[ df.Title == 'Programmer' ]['Salary'].groupby(data['Gender']).mean()
res3
# Out:
# Gender
# F    72500.769231
# M    72629.166667
# Name: Salary, dtype: float64
# Gender
# F    72500.769231
# M    72629.166667
# Name: Salary, dtype: float64

# %%
# Compare the average salary by department
res = data['Salary'].groupby(data.Department).mean()
res
# Out:
# Department
# Animation            59027.941176
# Art                  52222.000000
# Game Design          66400.000000
# Production           97500.000000
# Programming          79396.800000
# Quality Assurance    43204.545455
# Sound Design         62750.000000
# Name: Salary, dtype: float64

# %%
# Compare the average salary by department
res.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Compare the average salary of female employees in each title
df = data

# 1) Filter out female
res1 = df[ df.Gender == 'F']
res1

# 2) Group by department
res2 = res1.groupby(df.Department)
res2

# 3) Get average salary 
res3 = res2.Salary.mean()
res3

# 4 ) Sorting by
res4 = res3.sort_values(ascending= False)
res4.plot(kind ='bar', rot=60, title ='Female Salary By Department')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = data
res = df[ df.Gender == 'F'].groupby(df.Department).Salary.mean().sort_values(ascending = False)
res.plot(kind='bar', title ='Female Salary By Department',rot=60, color='g')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Group by Department, default is sort by index

res5 = data['ID'].groupby(data.Department).count()
print(res5)
res5.plot(kind='bar', title ='Employee Numbers By Department')
# Out:
# Department
# Animation            17
# Art                  25
# Game Design           5
# Production            2
# Programming          25
# Quality Assurance    11
# Sound Design          8
# Name: ID, dtype: int64
# <img src="data:image/png;base64,..." width="640">

# %%
# Group by Department, default is sort by index, can chance sorting by value

res5 = data['ID'].groupby(data.Department).count().sort_values()
res5 = data['ID'].groupby(data.Department).count().sort_values(ascending = False)
print(res5)
res5.plot(kind='bar', title ='Employee Numbers By Department')
# Out:
# Department
# Programming          25
# Art                  25
# Animation            17
# Quality Assurance    11
# Sound Design          8
# Game Design           5
# Production            2
# Name: ID, dtype: int64
# <img src="data:image/png;base64,..." width="640">

# %%
# Group by Department, can chance sorting by value
res5 = data.groupby(data.Department).Salary.mean().sort_values()
res5
# Out:
# Department
# Quality Assurance    43204.545455
# Art                  52222.000000
# Animation            59027.941176
# Sound Design         62750.000000
# Game Design          66400.000000
# Programming          79396.800000
# Production           97500.000000
# Name: Salary, dtype: float64

# %%
# Group by Department,  sort by value
res5.plot(kind='bar', title ='Salary By Department')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Group by Performance, show number of person

# 1） Groupby
res1 = data.groupby(data.Performance)

# 2) Select ID
res2 = data.groupby(data.Performance).ID

# 3) Get ID.count
res3 = data.groupby(data.Performance).ID.count()
res3

# 4) Sorting, sort_index  vs sort_values   / ascending = True vs ascending = False
res4 = res3.sort_values(ascending = False)
print(res4)
res4.plot(kind='bar', title = 'Employee Performance')
# Out:
# Performance
# Average      38
# Good         32
# Excellent    23
# Name: ID, dtype: int64
# <img src="data:image/png;base64,..." width="640">

# %%
res4.plot(kind='pie', title='Employee Performance',autopct='%1.1f%%')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Show the department which has the highest average salary
res = data['Salary'].groupby(data.Department).mean().sort_values(ascending=False)
print(res)

print(res.head(1))

print('--------Department which has the highest average salary')
print(res.index[0])        # res is serial, the first index and value
print(res.values[0])
# Out:
# Department
# Production           97500.000000
# Programming          79396.800000
# Game Design          66400.000000
# Sound Design         62750.000000
# Animation            59027.941176
# Art                  52222.000000
# Quality Assurance    43204.545455
# Name: Salary, dtype: float64
# --------Department which has the highest average salary
# Department
# Production    97500.0
# Name: Salary, dtype: float64
# Production
# 97500.0

# %% [markdown]
# # Groupby two columns

# %%
# Groupby two columns: data.Department, data.Gender
# Count number

# Step 1: groupby
res1 = data.groupby([data.Department, data.Gender])
res1

# Step 2: after groupby, select ID
res2 = res1.ID

# Step 3: apply a fuction
res3 = res2.count()
print(res3)

# Step 4 Sort: sort_index vs sort_values()
res4 = res3.sort_values(ascending=False)

# Step 5: plot
res4.plot(kind='bar', title= 'Employee number by Department and Gender', rot=45, color='g')
# Out:
# Department         Gender
# Animation          F         10
#                    M          7
# Art                F         18
#                    M          7
# Game Design        F          2
#                              ..
# Programming        M          9
# Quality Assurance  F          7
#                    M          4
# Sound Design       F          6
#                    M          2
# Name: ID, Length: 13, dtype: int64
# <img src="data:image/png;base64,..." width="640">

# %%
res4.plot(kind='barh')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(res4)
print('-----------')
print(res4.index)
print(res4.values)
print('-----------')
print(res4.index[0])
print(res4.values[0])
print('-----------')
print(res4.index[0][0])
print(res4.index[0][1])
print(res4.index[1][0])
print(res4.index[1][1])
# Out:
# Department         Gender
# Art                F         18
# Programming        F         16
# Animation          F         10
# Programming        M          9
# Quality Assurance  F          7
#                              ..
#                    M          4
# Game Design        M          3
# Sound Design       M          2
# Production         F          2
# Game Design        F          2
# Name: ID, Length: 13, dtype: int64
# -----------
# MultiIndex(levels=[['Animation', 'Art', 'Game Design', 'Production', 'Programming', 'Quality Assurance', 'Sound Design'], ['F', 'M']],
#            codes=[[1, 4, 0, 4, 5, 1, 0, 6, 5, 2, 6, 3, 2], [0, 0, 0, 1, 0, 1, 1, 0, 1, 1, 1, 0, 0]],
#            names=['Department', 'Gender'])
# [18 16 10  9  7  7  7  6  4  3  2  2  2]
# -----------
# ('Art', 'F')
# 18
# -----------
# Art
# F
# Programming
# F

# %%
# Use unstack for department and gender
res5 = res4.unstack()
res5
# Out:
# Gender                F    M
# Department
# Animation          10.0  7.0
# Art                18.0  7.0
# Game Design         2.0  3.0
# Production          2.0  NaN
# Programming        16.0  9.0
# Quality Assurance   7.0  4.0
# Sound Design        6.0  2.0

# %%
# Plot number of employees by department and gender
res5.plot(kind='barh', title='employees by department and gender')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Groupby two columns:  data.Performance, data.Gender
# Average salary
data
res = data.groupby([data.Performance, data.Gender]).Salary.mean().sort_values()
res
# Out:
# Performance  Gender
# Average      M         53031.250000
#              F         53966.346154
# Good         M         64312.307692
#              F         67228.157895
# Excellent    F         70471.875000
#              M         73964.285714
# Name: Salary, dtype: float64

# %%
res.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Use unstack
print(res)
print('\n---')
res = res.unstack()
print(res)
# Out:
# Performance  Gender
# Average      M         53031.250000
#              F         53966.346154
# Good         M         64312.307692
#              F         67228.157895
# Excellent    F         70471.875000
#              M         73964.285714
# Name: Salary, dtype: float64
#
# ---
# Gender                  F             M
# Performance
# Average      53966.346154  53031.250000
# Excellent    70471.875000  73964.285714
# Good         67228.157895  64312.307692

# %%
res.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Unstack vs. stack
res = data.groupby([data.Title, data.Gender]).size()
print(res)
print('\n---')
res = res.unstack()
print(res)

res = res.stack()
print('\n---')
print(res)
# Out:
# Title                  Gender
# Animator               F          7
#                        M          5
# Artist                 F         11
#                        M          3
# Executive Producer     F          1
#                                  ..
# Senior Programmer      M          2
# Senior QA Tester       F          2
# Senior Sound Designer  F          2
# Sound Designer         F          3
#                        M          2
# Length: 29, dtype: int64
#
# ---
# Gender                    F    M
# Title
# Animator                7.0  5.0
# Artist                 11.0  3.0
# Executive Producer      1.0  NaN
# Game Designer           NaN  2.0
# Lead Animator           1.0  NaN
# ...                     ...  ...
# Senior Game Designer    1.0  1.0
# Senior Programmer       3.0  2.0
# Senior QA Tester        2.0  NaN
# Senior Sound Designer   2.0  NaN
# Sound Designer          3.0  2.0
#
# [20 rows x 2 columns]
#
# ---
# Title                  Gender
# ...

# %%
# Another notation
res = data.groupby([data.Title, data.Gender]).size()
print(res)
res.plot(kind='bar')
# Out:
# Title                  Gender
# Animator               F          7
#                        M          5
# Artist                 F         11
#                        M          3
# Executive Producer     F          1
#                                  ..
# Senior Programmer      M          2
# Senior QA Tester       F          2
# Senior Sound Designer  F          2
# Sound Designer         F          3
#                        M          2
# Length: 29, dtype: int64
# <img src="data:image/png;base64,..." width="640">

# %%
print(res)
res = res.unstack()

print(res)

print('\---')
res = res.dropna()
print(res)
res.plot(kind='bar')
# Out:
# Title                  Gender
# Animator               F          7
#                        M          5
# Artist                 F         11
#                        M          3
# Executive Producer     F          1
#                                  ..
# Senior Programmer      M          2
# Senior QA Tester       F          2
# Senior Sound Designer  F          2
# Sound Designer         F          3
#                        M          2
# Length: 29, dtype: int64
# Gender                    F    M
# Title
# Animator                7.0  5.0
# Artist                 11.0  3.0
# Executive Producer      1.0  NaN
# Game Designer           NaN  2.0
# Lead Animator           1.0  NaN
# ...                     ...  ...
# Senior Game Designer    1.0  1.0
# Senior Programmer       3.0  2.0
# Senior QA Tester        2.0  NaN
# Senior Sound Designer   2.0  NaN
# Sound Designer          3.0  2.0
#
# [20 rows x 2 columns]
# \---
# Gender                   F    M
# Title
# ...

# %%
print('\n---')
res = data.Salary.groupby([data.Performance, data.Gender]).size().sort_values()
print(res)
print('\n---')
res = res.unstack()
print(res)
res.plot(kind='bar')
# Out:
# ---
# Performance  Gender
# Excellent    M          7
# Average      M         12
# Good         M         13
# Excellent    F         16
# Good         F         19
# Average      F         26
# Name: Salary, dtype: int64
#
# ---
# Gender        F   M
# Performance
# Average      26  12
# Excellent    16   7
# Good         19  13
# <img src="data:image/png;base64,..." width="640">
