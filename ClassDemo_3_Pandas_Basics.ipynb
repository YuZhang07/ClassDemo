# %% [markdown]
# # Pandas Basics

# %%
import pandas as pd

# %%
data = pd.read_csv('data/e05b2Game_salary.csv')

# %%
# limiting the display rows
pd.set_option('display.max_rows', 5)
data
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ..    ...       ...        ...    ...           ...                    ...
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance
# 0    67000     Average
# 1    80000        Good
# ..     ...         ...
# 91   90000   Excellent
# 92   75000        Good
#
# [93 rows x 8 columns]

# %%
data.head()
# Out:
#       ID Last Name First Name Gender    Department                  Title  \
# 0  10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1  10387    Felser    Cynthia      F     Animation          Lead Animator
# 2  10552    Leslie       Jean      F           Art                 Artist
# 3  10936     Cusak    Barbara      F   Programming             Programmer
# 4  11048     Noble      Linda      M   Game Design   Senior Game Designer
#
#    Salary Performance
# 0   67000     Average
# 1   80000        Good
# 2   45250     Average
# 3   70125     Average
# 4   72500   Excellent

# %%
data.shape
# Out:
# (93, 8)

# %%
# data.info?
data.info
# Out:
# <bound method DataFrame.info of        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ..    ...       ...        ...    ...           ...                    ...
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance
# 0    67000     Average
# 1    80000        Good
# ..     ...         ...
# 91   90000   Excellent
# 92   75000        Good
#
# [93 rows x 8 columns]>

# %%
data.columns
# Out:
# Index(['ID', 'Last Name', 'First Name', 'Gender', 'Department', 'Title',
#        'Salary', 'Performance'],
#       dtype='object')

# %%
print(data.shape)
# Out:
# (93, 8)

# %%
data.describe()
# Out:
#                  ID         Salary
# count     93.000000      93.000000
# mean   19267.075269   62346.182796
# ...             ...            ...
# 75%    23484.000000   70125.000000
# max    27474.000000  120000.000000
#
# [8 rows x 2 columns]

# %% [markdown]
# ## Drop Columns Method

# %%
# Some time, you need to drop columns

df = data
print(df.shape)

# del columns
#df = df.drop('Salary',axis =1)
# or
df = df.drop(['Salary'],axis =1)

print(df.shape)
print(data.shape)
# Out:
# (93, 8)
# (93, 7)
# (93, 8)

# %%
print(df.columns)
data.columns
# Out:
# Index(['ID', 'Last Name', 'First Name', 'Gender', 'Department', 'Title',
#        'Performance'],
#       dtype='object')
# Index(['ID', 'Last Name', 'First Name', 'Gender', 'Department', 'Title',
#        'Salary', 'Performance'],
#       dtype='object')

# %%
# Compare
for name in df.columns:
    print(name,end=' | ')

print('\n')
cols = data.columns
for name in cols:
    print(name,end=' | ')
# Out:
# ID | Last Name | First Name | Gender | Department | Title | Performance |
#
# ID | Last Name | First Name | Gender | Department | Title | Salary | Performance |

# %%
# Drop two columns
df = data
df = df.drop(['Title', 'Salary'], axis =1)

print(df.columns)
print(data.columns)
# Out:
# Index(['ID', 'Last Name', 'First Name', 'Gender', 'Department', 'Performance'], dtype='object')
# Index(['ID', 'Last Name', 'First Name', 'Gender', 'Department', 'Title',
#        'Salary', 'Performance'],
#       dtype='object')

# %%
# Compare
for name in df.columns:
    print(name,end=' | ')

print('\n')
cols = data.columns
for name in cols:
    print(name,end=' | ')
# Out:
# ID | Last Name | First Name | Gender | Department | Performance |
#
# ID | Last Name | First Name | Gender | Department | Title | Salary | Performance |

# %%
# deep copy, see the difference
df = data.copy()

df.drop(['Title', 'Salary'], axis =1)

print(df.columns)
print(data.columns)
# Out:
# Index(['ID', 'Last Name', 'First Name', 'Gender', 'Department', 'Title',
#        'Salary', 'Performance'],
#       dtype='object')
# Index(['ID', 'Last Name', 'First Name', 'Gender', 'Department', 'Title',
#        'Salary', 'Performance'],
#       dtype='object')

# %%
# Compare
for name in df.columns:
    print(name,end=' | ')

print('\n')
cols = data.columns
for name in cols:
    print(name,end=' | ')
# Out:
# ID | Last Name | First Name | Gender | Department | Title | Salary | Performance |
#
# ID | Last Name | First Name | Gender | Department | Title | Salary | Performance |

# %%
data.drop(['Title', 'Salary'], axis =1)
data
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ..    ...       ...        ...    ...           ...                    ...
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance
# 0    67000     Average
# 1    80000        Good
# ..     ...         ...
# 91   90000   Excellent
# 92   75000        Good
#
# [93 rows x 8 columns]

# %%
# You can drop values from the columns by passing axis=1 or axis='columns':

df = data.drop(['Title', 'Salary'], axis =1)
df
# Out:
#        ID Last Name First Name Gender    Department Performance
# 0   10000    Aikman       Gary      F  Sound Design     Average
# 1   10387    Felser    Cynthia      F     Animation        Good
# ..    ...       ...        ...    ...           ...         ...
# 91  27244  De Maria     Cristi      F   Programming   Excellent
# 92  27474     Elway    William      M   Programming        Good
#
# [93 rows x 6 columns]

# %%
# Examples: Drop rows
index = data[data['Gender']=='F'].index

index
# Out:
# Int64Index([ 0,  1,  2,  3,  5,  6,  8, 10, 11, 12, 14, 15, 17, 18, 19, 20, 21,
#             22, 24, 25, 28, 30, 31, 33, 34, 37, 38, 40, 41, 42, 43, 45, 46, 47,
#             48, 49, 50, 51, 52, 56, 57, 58, 59, 63, 64, 67, 68, 69, 70, 71, 75,
#             77, 78, 80, 81, 82, 84, 87, 88, 89, 91],
#            dtype='int64')

# %%
# data[data['Gender']=='F'].values

# %%
# Drop rows
# Just show the example, usually use filter, show in the next section
males = data.drop(index, axis=0)
print(males.shape)
print(data.shape)
# Out:
# (32, 8)
# (93, 8)

# %%
males
# Out:
#        ID Last Name First Name Gender   Department                 Title  \
# 4   11048     Noble      Linda      M  Game Design  Senior Game Designer
# 7   11447  Sampieri     Maylou      M  Programming            Programmer
# ..    ...       ...        ...    ...          ...                   ...
# 90  26896   Bermont     Thomas      M  Programming       Lead Programmer
# 92  27474     Elway    William      M  Programming            Programmer
#
#     Salary Performance
# 4    72500   Excellent
# 7    61000        Good
# ..     ...         ...
# 90  120000   Excellent
# 92   75000        Good
#
# [32 rows x 8 columns]

# %%
# Add a columns
# Add columns
data['Address'] ='SSPU'
data
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ..    ...       ...        ...    ...           ...                    ...
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance Address
# 0    67000     Average    SSPU
# 1    80000        Good    SSPU
# ..     ...         ...     ...
# 91   90000   Excellent    SSPU
# 92   75000        Good    SSPU
#
# [93 rows x 9 columns]

# %%
# Add a new member to the dataframe
# Check https://stackoverflow.com/questions/49916371/how-to-append-new-row-to-dataframe-in-pandas
# list
new =['999999','Zhang','Yu','F','Animation','Senior Programmer',75000,'Good','SSPU']
data.loc[len(data)] = new


data.tail()
# Out:
#         ID Last Name First Name Gender   Department              Title  \
# 91   27244  De Maria     Cristi      F  Programming         Programmer
# 92   27474     Elway    William      M  Programming         Programmer
# 93  999999     Zhang         Yu      F    Animation  Senior Programmer
# 94  999999     Zhang         Yu      F    Animation  Senior Programmer
# 95  999999     Zhang         Yu      F    Animation  Senior Programmer
#
#     Salary Performance Address
# 91   90000   Excellent    SSPU
# 92   75000        Good    SSPU
# 93   75000        Good    SSPU
# 94   75000        Good    SSPU
# 95   75000        Good    SSPU

# %%
# Concatenate with additional Index objects, producing a new Index
# Other way? append
# data.append?

res = data.append(new)
data.tail()
res.tail()
# Out:
#                    0 Address Department First Name Gender   ID Last Name  \
# 4          Animation     NaN        NaN        NaN    NaN  NaN       NaN
# 5  Senior Programmer     NaN        NaN        NaN    NaN  NaN       NaN
# 6              75000     NaN        NaN        NaN    NaN  NaN       NaN
# 7               Good     NaN        NaN        NaN    NaN  NaN       NaN
# 8               SSPU     NaN        NaN        NaN    NaN  NaN       NaN
#
#   Performance  Salary Title
# 4         NaN     NaN   NaN
# 5         NaN     NaN   NaN
# 6         NaN     NaN   NaN
# 7         NaN     NaN   NaN
# 8         NaN     NaN   NaN

# %%
# Delete just added rows
data[data.ID == '999999']
# Out:
#         ID Last Name First Name Gender Department              Title  Salary  \
# 93  999999     Zhang         Yu      F  Animation  Senior Programmer   75000
# 94  999999     Zhang         Yu      F  Animation  Senior Programmer   75000
# 95  999999     Zhang         Yu      F  Animation  Senior Programmer   75000
#
#    Performance Address
# 93        Good    SSPU
# 94        Good    SSPU
# 95        Good    SSPU

# %%
data.drop(index = data[data.ID=='999999'].index, axis =0, inplace=True)
data.tail()
# Out:
#        ID Last Name First Name Gender   Department            Title  Salary  \
# 88  26679   Whiting      Sarah      F    Animation         Animator   52500
# 89  26813    Denver        Jan      F  Programming       Programmer   58400
# 90  26896   Bermont     Thomas      M  Programming  Lead Programmer  120000
# 91  27244  De Maria     Cristi      F  Programming       Programmer   90000
# 92  27474     Elway    William      M  Programming       Programmer   75000
#
#    Performance Address
# 88        Good    SSPU
# 89     Average    SSPU
# 90   Excellent    SSPU
# 91   Excellent    SSPU
# 92        Good    SSPU

# %% [markdown]
# # Selection

# %%
data
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ..    ...       ...        ...    ...           ...                    ...
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance Address
# 0    67000     Average    SSPU
# 1    80000        Good    SSPU
# ..     ...         ...     ...
# 91   90000   Excellent    SSPU
# 92   75000        Good    SSPU
#
# [93 rows x 9 columns]

# %%
# only show one column

names = data['Last Name']  # this is a series

# %%
data['Last Name'].index
# Out:
# RangeIndex(start=0, stop=93, step=1)

# %%
data['Last Name'].values
# Out:
# array(['Aikman', 'Felser', 'Leslie', 'Cusak', 'Noble', 'Bobbitt',
#        'Lobree', 'Sampieri', 'Powell', 'Cole', 'Foerster', 'Guilford',
#        'Drubin', 'Spinale', 'Watson', 'Pennekamp', 'Fegin', 'Erpf',
#        'White', 'Jones', 'Jackson', 'Hood', 'Moss', 'Wilson', 'Ross',
#        'Martin', 'Scott', 'Park', 'Gonzalez', 'Wynperle', 'Wood', 'Hasty',
#        'North', 'Parker', 'Brawner', 'Fleming', 'Sade', 'Stieglitz',
#        'Munroe', 'Mills', 'Voell', 'Titley', 'Brett', 'Shuffield',
#        'Brickey', 'Mosely', 'Dill', 'Reed', 'Evans', 'Brooks', 'Strump',
#        'Payne', 'Lazarus', 'Jenks', 'Rapee', 'Gander', 'Restery', 'Park',
#        'Halloway', 'Moran', 'Shindell', 'Sapp', 'Rudy', 'Anderson',
#        'Afflord', 'Quinton', 'Justice', 'Jamison', 'Johnson', 'Simon',
#        'Munter', 'Williamson', 'Smith', 'Moynahan', 'Bogani', 'Holly',
#        'Goldstein', 'Figure', 'Adams', 'Carlo', 'Hoffman', 'Scola',
# ...

# %%
# Show first name, last name and title, , use [[]]!!!
data[['Last Name', 'First Name', 'Title']]
# Out:
#    Last Name First Name                  Title
# 0     Aikman       Gary  Senior Sound Designer
# 1     Felser    Cynthia          Lead Animator
# ..       ...        ...                    ...
# 91  De Maria     Cristi             Programmer
# 92     Elway    William             Programmer
#
# [93 rows x 3 columns]

# %%
data.ID

# Total employees, use count
data['ID'].count()

# also can use len
len(data['ID'])
# Out:
# 93

# %%
data
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ..    ...       ...        ...    ...           ...                    ...
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance
# 0    67000     Average
# 1    80000        Good
# ..     ...         ...
# 91   90000   Excellent
# 92   75000        Good
#
# [93 rows x 8 columns]

# %% [markdown]
# # Filtering

# %%
# 'Title' vs. data.Title
data[data.Title=='Programmer']

# vs.
data[data['Title']=='Programmer']
# Out:
#        ID Last Name First Name Gender   Department       Title  Salary  \
# 3   10936     Cusak    Barbara      F  Programming  Programmer   70125
# 7   11447  Sampieri     Maylou      M  Programming  Programmer   61000
# ..    ...       ...        ...    ...          ...         ...     ...
# 91  27244  De Maria     Cristi      F  Programming  Programmer   90000
# 92  27474     Elway    William      M  Programming  Programmer   75000
#
#    Performance
# 3      Average
# 7         Good
# ..         ...
# 91   Excellent
# 92        Good
#
# [19 rows x 8 columns]

# %%
# List all Female Senior Game Designer
data[(data['Title'] =='Senior Programmer') | (data['Gender'] =='F')]
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ..    ...       ...        ...    ...           ...                    ...
# 89  26813    Denver        Jan      F   Programming             Programmer
# 91  27244  De Maria     Cristi      F   Programming             Programmer
#
#     Salary Performance
# 0    67000     Average
# 1    80000        Good
# ..     ...         ...
# 89   58400     Average
# 91   90000   Excellent
#
# [63 rows x 8 columns]

# %%
# List all Female Senior Game Designer
data[(data['Title'] =='Senior Programmer') & (data['Gender'] =='F')]
# Out:
#        ID Last Name First Name Gender   Department              Title  Salary  \
# 5   11309   Bobbitt     Oronzo      F  Programming  Senior Programmer  105250
# 34  17604   Brawner      Missy      F  Programming  Senior Programmer   93750
# 42  18845     Brett       Phil      F  Programming  Senior Programmer   97500
#
#    Performance
# 5         Good
# 34     Average
# 42        Good

# %%
# List senior position or performance is Excellent
# Use contains
df = data

df = df[ (df.Title.str.contains('Senior')) | (df.Performance=='Exellent')]
df
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 4   11048     Noble      Linda      M   Game Design   Senior Game Designer
# ..    ...       ...        ...    ...           ...                    ...
# 83  25940  Fischler       Judy      M     Animation        Senior Animator
# 85  26341   Houston       Alex      M           Art          Senior Artist
#
#     Salary Performance
# 0    67000     Average
# 4    72500   Excellent
# ..     ...         ...
# 83   68750     Average
# 85   60000     Average
#
# [25 rows x 8 columns]

# %%
# Or
df = data
df= df[ (df.Title=='Senior Programmer') & (df.Gender=='F')]
# How many people satisfied the condition
df.ID.count()
# Out:
# 3

# %%
# Out:
# 93

# %% [markdown]
# # Use loc
# df[val]	Select single column or sequence of columns from the DataFrame; special case conveniences: boolean array (filter rows), slice (slice rows), or boolean DataFrame (set values based on some criterion)
# df.loc[val]	Selects single row or subset of rows from the DataFrame by label
# df.loc[:, val]	Selects single column or subset of columns by label
# df.loc[val1, val2]	Select both rows and columns by label
# df.iloc[where]	Selects single row or subset of rows from the DataFrame by integer position
# df.iloc[:, where]	Selects single column or subset of columns by integer position
# df.iloc[where_i, where_j]	Select both rows and columns by integer position

# %%
df = data
df.loc[0:5]
df.loc[10:15]
# Out:
#        ID  Last Name First Name Gender         Department             Title  \
# 10  12182   Foerster     Shelly      F          Animation   Senior Animator
# 11  12392   Guilford      Betty      F          Animation          Animator
# ..    ...        ...        ...    ...                ...               ...
# 14  12961     Watson       Fran      F        Programming        Programmer
# 15  13153  Pennekamp       Lynn      F  Quality Assurance  Senior QA Tester
#
#     Salary Performance Address
# 10   51250     Average    SSPU
# 11   58000        Good    SSPU
# ..     ...         ...     ...
# 14   85750   Excellent    SSPU
# 15   51000   Excellent    SSPU
#
# [6 rows x 9 columns]

# %%
#df.loc[val]	Selects single row or subset of rows from the DataFrame by label
df.loc[3]
# Out:
# ID               10936
# Last Name        Cusak
#                 ...
# Performance    Average
# Address           SSPU
# Name: 3, Length: 9, dtype: object

# %%
#df.loc[:, val]	Selects single column or subset of columns by label
df = data
df
df.loc[:, 'Last Name']
# Out:
# 0       Aikman
# 1       Felser
#         ...
# 91    De Maria
# 92       Elway
# Name: Last Name, Length: 93, dtype: object

# %%
df.loc[:, ['Last Name','Title']]
# Out:
#    Last Name                  Title
# 0     Aikman  Senior Sound Designer
# 1     Felser          Lead Animator
# ..       ...                    ...
# 91  De Maria             Programmer
# 92     Elway             Programmer
#
# [93 rows x 2 columns]

# %%
#df.loc[val1, val2]	Select both rows and columns by label
df.loc[[2], ['ID','Tilte']]
# Out:
#       ID  Tilte
# 2  10552    NaN

# %%
#df.iloc[where]	Selects single row or subset of rows from the DataFrame by integer position
df.iloc[index<10]
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ..    ...       ...        ...    ...           ...                    ...
# 5   11309   Bobbitt     Oronzo      F   Programming      Senior Programmer
# 6   11390    Lobree      Cindy      F           Art                 Artist
#
#     Salary Performance Address
# 0    67000     Average    SSPU
# 1    80000        Good    SSPU
# ..     ...         ...     ...
# 5   105250        Good    SSPU
# 6    46125     Average    SSPU
#
# [7 rows x 9 columns]

# %%
df.iloc[10]
# Out:
# ID                12182
# Last Name      Foerster
#                  ...
# Performance     Average
# Address            SSPU
# Name: 10, Length: 9, dtype: object

# %%
df.iloc[[1,2],[0,1,2]]
# Out:
#       ID Last Name First Name
# 1  10387    Felser    Cynthia
# 2  10552    Leslie       Jean

# %% [markdown]
# #Use .loc to assign column values

# %%
# Compute bonus
# Excellent: 10%
# Good: 6%
# Average: 3%

df = data
df['Bonus']=0
df
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ..    ...       ...        ...    ...           ...                    ...
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance Address  Bonus
# 0    67000     Average    SSPU      0
# 1    80000        Good    SSPU      0
# ..     ...         ...     ...    ...
# 91   90000   Excellent    SSPU      0
# 92   75000        Good    SSPU      0
#
# [93 rows x 10 columns]

# %%
# Method 1
ex_bonus = df[df.Performance=='Excellent'].Salary*0.1
df['Bonus']= ex_bonus
df
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ..    ...       ...        ...    ...           ...                    ...
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance Address   Bonus
# 0    67000     Average    SSPU     NaN
# 1    80000        Good    SSPU     NaN
# ..     ...         ...     ...     ...
# 91   90000   Excellent    SSPU  9000.0
# 92   75000        Good    SSPU     NaN
#
# [93 rows x 10 columns]

# %%
#df.sort_values?
df.sort_values(by = 'Salary',ascending=False).head()
# Out:
#        ID Last Name First Name Gender   Department               Title  \
# 90  26896   Bermont     Thomas      M  Programming     Lead Programmer
# 5   11309   Bobbitt     Oronzo      F  Programming   Senior Programmer
# 33  17466    Parker     Angela      F   Production  Executive Producer
# 74  24334    Bogani       Jane      M  Programming   Senior Programmer
# 42  18845     Brett       Phil      F  Programming   Senior Programmer
#
#     Salary Performance Address    Bonus
# 90  120000   Excellent    SSPU  12000.0
# 5   105250        Good    SSPU      NaN
# 33  105000   Excellent    SSPU  10500.0
# 74  100135        Good    SSPU      NaN
# 42   97500        Good    SSPU      NaN

# %%
# Use another method
# Use loc to assign value?
# df.drop('bonus',axis=1,inplace=True)
df['Bonus']=0
data
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ..    ...       ...        ...    ...           ...                    ...
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance Address  Bonus
# 0    67000     Average    SSPU      0
# 1    80000        Good    SSPU      0
# ..     ...         ...     ...    ...
# 91   90000   Excellent    SSPU      0
# 92   75000        Good    SSPU      0
#
# [93 rows x 10 columns]

# %%
ex_index = df[df.Performance=='Excellent'].index

df.loc[ex_index,'Bonus']
# Out:
# 4     0
# 8     0
#      ..
# 90    0
# 91    0
# Name: Bonus, Length: 23, dtype: int64

# %%
df.loc[ex_index,'Salary']
# Out:
# 4      72500
# 8      45000
#        ...
# 90    120000
# 91     90000
# Name: Salary, Length: 23, dtype: int64

# %%
df.loc[ex_index,'Bonus'] = df.loc[ex_index,'Salary']*.01
df.loc[ex_index,'Bonus']
# Out:
# 4      725.0
# 8      450.0
#        ...
# 90    1200.0
# 91     900.0
# Name: Bonus, Length: 23, dtype: float64

# %%
df.sort_values(by='Bonus',ascending = False)
# Out:
#        ID Last Name First Name Gender   Department               Title  \
# 90  26896   Bermont     Thomas      M  Programming     Lead Programmer
# 33  17466    Parker     Angela      F   Production  Executive Producer
# ..    ...       ...        ...    ...          ...                 ...
# 32  17226     North      Kathy      M  Game Design       Game Designer
# 92  27474     Elway    William      M  Programming          Programmer
#
#     Salary Performance Address   Bonus
# 90  120000   Excellent    SSPU  1200.0
# 33  105000   Excellent    SSPU  1050.0
# ..     ...         ...     ...     ...
# 32   57250        Good    SSPU     0.0
# 92   75000        Good    SSPU     0.0
#
# [93 rows x 10 columns]

# %%
# Same
df['Bonus']= 0
print(df.head())

# Use \ to change lines
df.loc[(df.Performance=='Excellent'), 'Bonus'] \    
   = df.loc[(df.Performance=='Excellent'),'Salary']*0.1
df
# Out:
#       ID Last Name First Name Gender    Department                  Title  \
# 0  10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1  10387    Felser    Cynthia      F     Animation          Lead Animator
# 2  10552    Leslie       Jean      F           Art                 Artist
# 3  10936     Cusak    Barbara      F   Programming             Programmer
# 4  11048     Noble      Linda      M   Game Design   Senior Game Designer
#
#    Salary Performance Address  Bonus
# 0   67000     Average    SSPU      0
# 1   80000        Good    SSPU      0
# 2   45250     Average    SSPU      0
# 3   70125     Average    SSPU      0
# 4   72500   Excellent    SSPU      0
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ...

# %%
len(df[df.Performance=='Excellent'].index)
# Out:
# 23

# %% [markdown]
# # Arithmetic methods with fill values

# %%
#Df3 = df1.add(df2, fill_value=0)
df['total']=df['Salary'].add(df.Bonus, fill_value=0)
df
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# ..    ...       ...        ...    ...           ...                    ...
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance Address   Bonus    total
# 0    67000     Average    SSPU     0.0  67000.0
# 1    80000        Good    SSPU     0.0  80000.0
# ..     ...         ...     ...     ...      ...
# 91   90000   Excellent    SSPU  9000.0  99000.0
# 92   75000        Good    SSPU     0.0  75000.0
#
# [93 rows x 11 columns]

# %% [markdown]
# # Sorting
#
# df.sort_values(by=['a','b'])

# %%
df.sort_values?

Signature:
df.sort_values(
    by,
    axis=0,
    ascending=True,
    inplace=False,
    kind='quicksort',
    na_position='last',
)
Docstring:
Sort by the values along either axis

Parameters
----------
        by : str or list of str
            Name or list of names to sort by.

            - if `axis` is 0 or `'index'` then `by` may contain index
              levels and/or column labels
            - if `axis` is 1 or `'columns'` then `by` may contain column
              levels and/or index labels

            .. versionchanged:: 0.23.0
               Allow specifying index or column level names.
axis : {0 or 'index', 1 or 'columns'}, default 0
     Axis to be sorted
ascending : bool or list of bool, default True
     Sort ascending vs. descending. Specify list for multiple sort
     orders.  If this is a list of bools, must match the length of
     the by.
inplace : bool, default False
     if True, perform operation in-place
kind : {'quicksort', 'mergesort', 'heapsort'}, default 'quicksort'
     Choice of sorting algorithm. See also ndarray.np.sort for more
     information.  `mergesort` is the only stable algorithm. For
     DataFrames, this option is only applied when sorting on a single
     column or label.
na_position : {'first', 'last'}, default 'last'
     `first` puts NaNs at the beginning, `last` puts NaNs at the end

Returns
-------
sorted_obj : DataFrame

Examples
--------
>>> df = pd.DataFrame({
...     'col1' : ['A', 'A', 'B', np.nan, 'D', 'C'],
...     'col2' : [2, 1, 9, 8, 7, 4],
...     'col3': [0, 1, 9, 4, 2, 3],
... })
>>> df
    col1 col2 col3
0   A    2    0
1   A    1    1
2   B    9    9
3   NaN  8    4
4   D    7    2
5   C    4    3

Sort by col1

>>> df.sort_values(by=['col1'])
    col1 col2 col3
0   A    2    0
1   A    1    1
2   B    9    9
5   C    4    3
4   D    7    2
3   NaN  8    4

Sort by multiple columns

>>> df.sort_values(by=['col1', 'col2'])
    col1 col2 col3
1   A    1    1
0   A    2    0
2   B    9    9
5   C    4    3
4   D    7    2
3   NaN  8    4

Sort Descending

>>> df.sort_values(by='col1', ascending=False)
    col1 col2 col3
4   D    7    2
5   C    4    3
2   B    9    9
0   A    2    0
1   A    1    1
3   NaN  8    4

Putting NAs first

>>> df.sort_values(by='col1', ascending=False, na_position='first')
    col1 col2 col3
3   NaN  8    4
4   D    7    2
5   C    4    3
2   B    9    9
0   A    2    0
1   A    1    1
File:      c:\users\jzhan\appdata\local\continuum\anaconda3\lib\site-packages\pandas\core\frame.py
Type:      method

# %%
df.sort_values(by='Bonus',ascending = False)
# Out:
#        ID Last Name First Name Gender   Department               Title  \
# 90  26896   Bermont     Thomas      M  Programming     Lead Programmer
# 33  17466    Parker     Angela      F   Production  Executive Producer
# ..    ...       ...        ...    ...          ...                 ...
# 32  17226     North      Kathy      M  Game Design       Game Designer
# 92  27474     Elway    William      M  Programming          Programmer
#
#     Salary Performance Address    Bonus
# 90  120000   Excellent    SSPU  12000.0
# 33  105000   Excellent    SSPU  10500.0
# ..     ...         ...     ...      ...
# 32   57250        Good    SSPU      0.0
# 92   75000        Good    SSPU      0.0
#
# [93 rows x 10 columns]

# %%
# List top three who has the Highest bonus
res = df.sort_values(by='Bonus',ascending = False).head(3)
res
# Out:
#        ID Last Name First Name Gender   Department                      Title  \
# 90  26896   Bermont     Thomas      M  Programming            Lead Programmer
# 33  17466    Parker     Angela      F   Production         Executive Producer
# 57  21766      Park      Terry      F   Production  Producer: Product Manager
#
#     Salary Performance Address    Bonus     total
# 90  120000   Excellent    SSPU  12000.0  132000.0
# 33  105000   Excellent    SSPU  10500.0  115500.0
# 57   90000   Excellent    SSPU   9000.0   99000.0

# %%
df.sort_values(by=['Title','Salary'],ascending = False).head(20)
# Out:
#        ID Last Name First Name Gender    Department           Title  Salary  \
# 13  12593   Spinale      Lorna      M  Sound Design  Sound Designer   61250
# 36  17699      Sade      Ringo      M  Sound Design  Sound Designer   55000
# 63  22920  Anderson       Jeff      F  Sound Design  Sound Designer   55000
# 50  20228    Strump      David      F  Sound Design  Sound Designer   53250
# ..    ...       ...        ...    ...           ...             ...     ...
# 29  16401  Wynperle    Allison      M           Art   Senior Artist   70000
# 19  13703     Jones   Maryanne      F           Art   Senior Artist   65800
# 21  14196      Hood       Joan      F           Art   Senior Artist   65000
# 30  16760      Wood      Jimmy      F           Art   Senior Artist   65000
#
#    Performance Address   Bonus    total
# 13   Excellent    SSPU  6125.0  67375.0
# 36   Excellent    SSPU  5500.0  60500.0
# 63   Excellent    SSPU  5500.0  60500.0
# 50     Average    SSPU     0.0  53250.0
# ...

# %%
# List three famaleiprogrammer who have the lowest sarlary

res1 = df[(df.Gender=='F') & (df.Title=='Programmer')].sort_values(by ='Salary').tail(3)

res2 = df[(df.Gender=='M') & (df.Title=='Programmer')].sort_values(by ='Salary').tail(3)

print(res1)
print(res2)
# Out:
#        ID Last Name First Name Gender   Department       Title  Salary  \
# 17  13638      Erpf   Meredith      F  Programming  Programmer   85800
# 18  13694     White       Jack      F  Programming  Programmer   89000
# 91  27244  De Maria     Cristi      F  Programming  Programmer   90000
#
#    Performance Address   Bonus    total
# 17   Excellent    SSPU  8580.0  94380.0
# 18   Excellent    SSPU  8900.0  97900.0
# 91   Excellent    SSPU  9000.0  99000.0
#        ID Last Name First Name Gender   Department       Title  Salary  \
# 92  27474     Elway    William      M  Programming  Programmer   75000
# 79  25190     Carlo     Criste      M  Programming  Programmer   82425
# 16  13183     Fegin      Nancy      M  Programming  Programmer   89000
#
#    Performance Address   Bonus    total
# 92        Good    SSPU     0.0  75000.0
# 79        Good    SSPU     0.0  82425.0
# 16   Excellent    SSPU  8900.0  97900.0

# %%
# List all above average salary

df[df.Salary > df.Salary.mean()]
# Out:
#        ID Last Name First Name Gender    Department                  Title  \
# 0   10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1   10387    Felser    Cynthia      F     Animation          Lead Animator
# 3   10936     Cusak    Barbara      F   Programming             Programmer
# 4   11048     Noble      Linda      M   Game Design   Senior Game Designer
# ..    ...       ...        ...    ...           ...                    ...
# 84  26148    Munroe    Eleanor      F   Game Design     Lead Game Designer
# 90  26896   Bermont     Thomas      M   Programming        Lead Programmer
# 91  27244  De Maria     Cristi      F   Programming             Programmer
# 92  27474     Elway    William      M   Programming             Programmer
#
#     Salary Performance Address    Bonus     total
# 0    67000     Average    SSPU      0.0   67000.0
# 1    80000        Good    SSPU      0.0   80000.0
# 3    70125     Average    SSPU      0.0   70125.0
# ...

# %% [markdown]
# # Summarizing and Computing Descriptive Statistics

# %%
# Include all
pd.set_option('display.max_rows', 8)
df.describe()
# Out:
#               Salary         Bonus          total
# count      93.000000     93.000000      93.000000
# mean    62346.182796   1769.139785   64115.322581
# std     18004.230095   3258.829697   19683.830304
# min     35000.000000      0.000000   35000.000000
# 25%     50000.000000      0.000000   50000.000000
# 50%     60000.000000      0.000000   60500.000000
# 75%     70125.000000      0.000000   71000.000000
# max    120000.000000  12000.000000  132000.000000

# %%
df.Salary.mean()
# Out:
# 62346.18279569892

# %%
ans = df.Salary.mean()
print(format(ans, ',.2f'))
# Out:
# 62,346.18

# %%
print(format(df.Salary.sum(), ',.2f'))
# Out:
# 5,798,195.00

# %%
df=data
res1 = df[(df.Gender=='F') & (df.Title=='Programmer')].Salary.mean()

res2 = df[(df.Gender=='M') & (df.Title=='Programmer')].Salary.mean()

print(res1)
print(res2)
# Out:
# 72500.76923076923
# 72629.16666666667

# %%
# Use
df=data

res1 = df[(df.Gender=='F') & (df.Title=='Programmer')].loc[:,'Salary'].mean()

res2 = df[(df.Gender=='M') & (df.Title=='Programmer')].loc[:,'Salary'].mean()

print(res1)
print(res2)
# Out:
# 72500.76923076923
# 72629.16666666667

# %%
df = data
res1 = df[(df.Gender=='F') & (df.Title=='Programmer')].ID.count()

res2 = df[(df.Gender=='M') & (df.Title=='Programmer')].ID.count()

print(res1)
print(res2)
# Out:
# 13
# 6

# %%
df = data
res1 = len(df[(df.Gender=='F') & (df.Title=='Programmer')])

res2 = len(df[(df.Gender=='M') & (df.Title=='Programmer')])

print(res1)
print(res2)
# Out:
# 13
# 6

# %%
df = data

res = df.Title.value_counts()

print(res.values)
print(res.index)
# Out:
# [19 14 12 10  8  5  5  4  2  2  2  2  1  1  1  1  1  1  1  1]
# Index(['Programmer', 'Artist', 'Animator', 'Senior Artist', 'QA Tester',
#        'Senior Programmer', 'Sound Designer', 'Senior Animator',
#        'Senior Game Designer', 'Game Designer', 'Senior QA Tester',
#        'Senior Sound Designer', 'Lead Programmer', 'Executive Producer',
#        'Lead Animator', 'Lead Sound Designer', 'Lead Artist', 'Lead QA Tester',
#        'Producer: Product Manager', 'Lead Game Designer'],
#       dtype='object')

# %%
res2 = res[res.values>5]
res2
# Out:
# Programmer       19
# Artist           14
# Animator         12
# Senior Artist    10
# QA Tester         8
# Name: Title, dtype: int64

# %%
res2.sort_index()
# Out:
# Animator         12
# Artist           14
# Programmer       19
# QA Tester         8
# Senior Artist    10
# Name: Title, dtype: int64

# %%
res = res2.sort_index()
res.plot(kind='Bar', color='b',title='Number of Title')

# %%
x = df.Title.value_counts().head(5)
x = x.sort_values()
x.plot(kind='bar')

# %%
# List all 
list = data.Department.unique()
list
# Out:
# array(['Sound Design', 'Animation', 'Art', 'Programming', 'Game Design',
#        'Quality Assurance', 'Production'], dtype=object)

# %%
len(data.Department.unique())
# Out:
# 7

# %%
# List all title
print('--Title')
print(data.Title.unique())
print('--Department')
print(data.Department.unique())
print('--Performance')
print(data['Performance'].unique())
# Out:
# --Title
# ['Senior Sound Designer' 'Lead Animator' 'Artist' 'Programmer'
#  'Senior Game Designer' 'Senior Programmer' 'QA Tester' 'Senior Animator'
#  'Animator' 'Sound Designer' 'Senior QA Tester' 'Senior Artist'
#  'Game Designer' 'Executive Producer' 'Producer: Product Manager'
#  'Lead Artist' 'Lead Sound Designer' 'Lead Game Designer' 'Lead QA Tester'
#  'Lead Programmer']
# --Department
# ['Sound Design' 'Animation' 'Art' 'Programming' 'Game Design'
#  'Quality Assurance' 'Production']
# --Performance
# ['Average' 'Good' 'Excellent']

# %%
for dpt in list:
    print(dpt)
# Out:
# Sound Design
# Animation
# Art
# Programming
# Game Design
# Quality Assurance
# Production

# %%
# Sorting
# Top 10 salary
df.sort_values(by ='Salary', ascending = False).head(3)

# %%
# Summary Statistics
print(df.Salary.mean())
print(df.Salary.max())
print(df.Salary.min())
print(df.Salary.sum())
print(df.Salary.std())
print(df.Salary.median())
